# %%
import time
import torch
import torch.nn as nn
import numpy as np
import module
from train import train, eval_, normal_grad, newton_grad
from dataset_wrapper import Cifar10Wrapper
import module
import matplotlib.pyplot as plt
import random


class Cifar10Model1(nn.Module):
    def __init__(self):
        super(Cifar10Model1, self).__init__()

        model = module.Sequential()
        # model.add_module('c1', nn.Conv2d(3, 33, 3, 2, 1))
        # model.add_module('relu1', nn.ReLU())
        # model.add_module('c2', nn.Conv2d(33, 64, 3, 2, 1))
        # model.add_module('relu2', nn.ReLU())
        # model.add_module('l3', nn.Conv2d(64, 128, 3, 2, 1))
        # model.add_module('relu3', nn.ReLU())
        # model.add_module('avg_pool', nn.AvgPool2d(4))

        model.add_module('c1', module.WnConv2d(3, 33, 3, 2, 1))
        model.add_module('relu1', nn.ReLU())
        model.add_module('c2', module.WnConv2d(33, 64, 3, 2, 1))
        model.add_module('relu2', nn.ReLU())
        model.add_module('l3', module.WnConv2d(64, 128, 3, 2, 1))
        model.add_module('relu3', nn.ReLU())
        model.add_module('avg_pool', nn.AvgPool2d(4))
        self.main = model
        # self.fc = module.WnLinear(128, 10)
        self.fc = nn.Linear(128, 10)

    def get_param_g(self):
        return self.main.get_param_g() + [self.fc.get_param_g()]

    def forward(self, x):
        y = self.main(x).squeeze()
        y = self.fc(y)
        return y


class Cifar10Model2(nn.Module):
    def __init__(self):
        super(Cifar10Model2, self).__init__()

        model = module.Sequential()
        model.add_module('c1', nn.Conv2d(3, 32, 3, 2, 1))
        model.add_module('relu1', nn.ReLU())
        model.add_module('c2', nn.Conv2d(32, 64, 3, 2, 1))
        model.add_module('relu2', nn.ReLU())
        model.add_module('l3', nn.Conv2d(64, 128, 3, 2, 1))
        model.add_module('relu3', nn.ReLU())
        model.add_module('avg_pool', nn.AvgPool2d(4))
        self.main = model
        self.fc = nn.Linear(128, 10)

    def get_param_g(self):
        return self.main.get_param_g() + [self.fc.get_param_g()]

    def forward(self, x):
        y = self.main(x).squeeze()
        y = self.fc(y)
        return y


def set_all_seeds(rand_seed):
    def large_randint():
        return random.randint(int(1e5), int(1e6))

    random.seed(rand_seed)
    np.random.seed(large_randint())
    torch.manual_seed(large_randint())
    torch.cuda.manual_seed(large_randint())

# %%
set_all_seeds(100009)

dataset = Cifar10Wrapper.load_default()
dataset.train_ys = dataset.train_ys.astype(np.int32).reshape((-1,))
dataset.test_ys = dataset.test_ys.astype(np.int32).reshape((-1,))
print dataset.train_ys.min()
print dataset.train_xs.min(), dataset.train_xs.max()
print dataset.train_xs.shape
# Out:
# Dataset loaded from /home/hengyuah/datasets/cifar10/cifar10.h5
# 0
# -1.0 1.0
# (50000, 3, 32, 32)

# %%
epochs = 20

wn_model = Cifar10Model1().cuda()
t = time.time()
_, wn_train_acc, wn_test_acc, wn_times = train(wn_model, dataset, normal_grad, 0.1, False, epochs)
print 'time:', time.time() - t

wn_kfac_model = Cifar10Model1().cuda()
t = time.time()
_, wn_kfac_train_acc, wn_kfac_test_acc, wn_kfac_times = train(wn_kfac_model, dataset, normal_grad, 0.1, True, epochs)
print 'time:', time.time() - t

model = Cifar10Model2().cuda()
t = time.time()
_, train_acc, test_acc, times = train(model, dataset, normal_grad, 0.1, False, epochs)
print 'time:', time.time() - t

kfac_model = Cifar10Model2().cuda()
t = time.time()
_, kfac_train_acc, kfac_test_acc, kfac_times = train(kfac_model, dataset, normal_grad, 0.1, True, epochs)
print 'time:', time.time() - t
# Out:
# epoch: 1, loss: 1.9483
# accumulate time 1.42750406265
# train acc: 0.34964
# eval acc: 0.352
# ----------------
# epoch: 2, loss: 1.6738
# accumulate time 2.83571887016
# train acc: 0.43434
# eval acc: 0.4414
# ----------------
# epoch: 3, loss: 1.5315
# accumulate time 4.24497485161
# train acc: 0.47878
# eval acc: 0.4762
# ----------------
# epoch: 4, loss: 1.4431
# accumulate time 5.65098905563
# train acc: 0.497
# eval acc: 0.4922
# ----------------
# epoch: 5, loss: 1.3759
# accumulate time 7.06046795845
# train acc: 0.53364
# eval acc: 0.5238
# ----------------
# epoch: 6, loss: 1.3169
# accumulate time 8.46775484085
# train acc: 0.52498
# eval acc: 0.5107
# ----------------
# epoch: 7, loss: 1.2687
# accumulate time 9.8728659153
# train acc: 0.56068
# eval acc: 0.552
# ----------------
# epoch: 8, loss: 1.2257
# accumulate time 11.281414032
# train acc: 0.58208
# eval acc: 0.5681
# ----------------
# epoch: 9, loss: 1.1870
# accumulate time 12.6903269291
# train acc: 0.56282
# eval acc: 0.5432
# ----------------
# epoch: 10, loss: 1.1522
# accumulate time 14.1062719822
# train acc: 0.58676
# eval acc: 0.5691
# ----------------
# epoch: 11, loss: 1.1168
# accumulate time 15.5106079578
# train acc: 0.62284
# eval acc: 0.6014
# ----------------
# epoch: 12, loss: 1.0897
# accumulate time 16.9203510284
# train acc: 0.63396
# eval acc: 0.6096
# ----------------
# epoch: 13, loss: 1.0604
# accumulate time 18.332392931
# train acc: 0.64462
# eval acc: 0.6128
# ----------------
# epoch: 14, loss: 1.0301
# accumulate time 19.7428238392
# train acc: 0.64044
# eval acc: 0.6135
# ----------------
# epoch: 15, loss: 1.0074
# accumulate time 21.1530120373
# train acc: 0.66694
# eval acc: 0.632
# ----------------
# epoch: 16, loss: 0.9803
# accumulate time 22.5675389767
# train acc: 0.67514
# eval acc: 0.6375
# ----------------
# epoch: 17, loss: 0.9547
# accumulate time 23.9809980392
# train acc: 0.68732
# eval acc: 0.6431
# ----------------
# epoch: 18, loss: 0.9317
# accumulate time 25.3922669888
# train acc: 0.69144
# eval acc: 0.6451
# ----------------
# epoch: 19, loss: 0.9078
# accumulate time 26.8031890392
# train acc: 0.66652
# eval acc: 0.6215
# ----------------
# epoch: 20, loss: 0.8933
# accumulate time 28.2145390511
# train acc: 0.7151
# eval acc: 0.658
# ----------------
# time: 28.2151479721
# epoch: 1, loss: 1.6886
# accumulate time 7.97985887527
# train acc: 0.47288
# eval acc: 0.4657
# ----------------
# epoch: 2, loss: 1.3517
# accumulate time 15.9854609966
# train acc: 0.55024
# eval acc: 0.5397
# ----------------
# epoch: 3, loss: 1.1969
# accumulate time 23.9751429558
# train acc: 0.6006
# eval acc: 0.5844
# ----------------
# epoch: 4, loss: 1.1008
# accumulate time 31.9810829163
# train acc: 0.63892
# eval acc: 0.6132
# ----------------
# epoch: 5, loss: 1.0220
# accumulate time 40.0207979679
# train acc: 0.66776
# eval acc: 0.6344
# ----------------
# epoch: 6, loss: 0.9600
# accumulate time 48.0176999569
# train acc: 0.6917
# eval acc: 0.6482
# ----------------
# epoch: 7, loss: 0.8998
# accumulate time 56.0504579544
# train acc: 0.7086
# eval acc: 0.6603
# ----------------
# epoch: 8, loss: 0.8451
# accumulate time 64.0588779449
# train acc: 0.72974
# eval acc: 0.6677
# ----------------
# epoch: 9, loss: 0.7985
# accumulate time 72.0897300243
# train acc: 0.73954
# eval acc: 0.6625
# ----------------
# epoch: 10, loss: 0.7535
# accumulate time 80.0921928883
# train acc: 0.7656
# eval acc: 0.6735
# ----------------
# epoch: 11, loss: 0.7087
# accumulate time 88.0970048904
# train acc: 0.7831
# eval acc: 0.6773
# ----------------
# epoch: 12, loss: 0.6694
# accumulate time 96.1246578693
# train acc: 0.80096
# eval acc: 0.6832
# ----------------
# epoch: 13, loss: 0.6332
# accumulate time 104.135643959
# train acc: 0.81116
# eval acc: 0.6827
# ----------------
# epoch: 14, loss: 0.5960
# accumulate time 112.144748926
# train acc: 0.83016
# eval acc: 0.6827
# ----------------
# epoch: 15, loss: 0.5600
# accumulate time 120.176440954
# train acc: 0.84264
# eval acc: 0.6883
# ----------------
# epoch: 16, loss: 0.5259
# accumulate time 128.211860895
# train acc: 0.85878
# eval acc: 0.6898
# ----------------
# epoch: 17, loss: 0.4927
# accumulate time 136.235828876
# train acc: 0.8659
# eval acc: 0.6862
# ----------------
# epoch: 18, loss: 0.4620
# accumulate time 144.264271975
# train acc: 0.88088
# eval acc: 0.6833
# ----------------
# epoch: 19, loss: 0.4277
# accumulate time 152.282768011
# train acc: 0.88782
# eval acc: 0.6786
# ----------------
# epoch: 20, loss: 0.3984
# accumulate time 160.316555977
# train acc: 0.90506
# eval acc: 0.6788
# ----------------
# time: 160.317994118
# epoch: 1, loss: 2.1154
# accumulate time 1.25272583961
# train acc: 0.25616
# eval acc: 0.2582
# ----------------
# epoch: 2, loss: 1.8750
# accumulate time 2.51100802422
# train acc: 0.33218
# eval acc: 0.3354
# ----------------
# epoch: 3, loss: 1.7350
# accumulate time 3.76589202881
# train acc: 0.38838
# eval acc: 0.3923
# ----------------
# epoch: 4, loss: 1.6234
# accumulate time 5.01996302605
# train acc: 0.40648
# eval acc: 0.4106
# ----------------
# epoch: 5, loss: 1.5428
# accumulate time 6.2730948925
# train acc: 0.449
# eval acc: 0.4482
# ----------------
# epoch: 6, loss: 1.4744
# accumulate time 7.5286090374
# train acc: 0.4845
# eval acc: 0.4851
# ----------------
# epoch: 7, loss: 1.4224
# accumulate time 8.78106999397
# train acc: 0.45434
# eval acc: 0.4513
# ----------------
# epoch: 8, loss: 1.3794
# accumulate time 10.0341699123
# train acc: 0.5251
# eval acc: 0.5176
# ----------------
# epoch: 9, loss: 1.3308
# accumulate time 11.285089016
# train acc: 0.537
# eval acc: 0.5288
# ----------------
# epoch: 10, loss: 1.2903
# accumulate time 12.5365138054
# train acc: 0.5409
# eval acc: 0.5315
# ----------------
# epoch: 11, loss: 1.2526
# accumulate time 13.7940289974
# train acc: 0.54766
# eval acc: 0.5378
# ----------------
# epoch: 12, loss: 1.2156
# accumulate time 15.0516419411
# train acc: 0.57916
# eval acc: 0.5592
# ----------------
# epoch: 13, loss: 1.1851
# accumulate time 16.3020429611
# train acc: 0.60902
# eval acc: 0.5916
# ----------------
# epoch: 14, loss: 1.1535
# accumulate time 17.5605559349
# train acc: 0.597
# eval acc: 0.5714
# ----------------
# epoch: 15, loss: 1.1207
# accumulate time 18.8175740242
# train acc: 0.60936
# eval acc: 0.5868
# ----------------
# epoch: 16, loss: 1.0959
# accumulate time 20.0722408295
# train acc: 0.62426
# eval acc: 0.6032
# ----------------
# epoch: 17, loss: 1.0697
# accumulate time 21.3327870369
# train acc: 0.65104
# eval acc: 0.6194
# ----------------
# epoch: 18, loss: 1.0448
# accumulate time 22.5918569565
# train acc: 0.64376
# eval acc: 0.616
# ----------------
# epoch: 19, loss: 1.0221
# accumulate time 23.8465969563
# train acc: 0.64406
# eval acc: 0.6085
# ----------------
# epoch: 20, loss: 0.9994
# accumulate time 25.1020629406
# train acc: 0.66092
# eval acc: 0.6261
# ----------------
# time: 25.1027011871
# epoch: 1, loss: 1.7610
# accumulate time 6.68805789948
# train acc: 0.4591
# eval acc: 0.4556
# ----------------
# epoch: 2, loss: 1.3897
# accumulate time 13.3245229721
# train acc: 0.54812
# eval acc: 0.5398
# ----------------
# epoch: 3, loss: 1.2061
# accumulate time 19.994024992
# train acc: 0.60644
# eval acc: 0.5912
# ----------------
# epoch: 4, loss: 1.0804
# accumulate time 26.6445260048
# train acc: 0.64612
# eval acc: 0.6208
# ----------------
# epoch: 5, loss: 0.9863
# accumulate time 33.317250967
# train acc: 0.67922
# eval acc: 0.6399
# ----------------
# epoch: 6, loss: 0.9149
# accumulate time 39.9880239964
# train acc: 0.6964
# eval acc: 0.6449
# ----------------
# epoch: 7, loss: 0.8541
# accumulate time 46.6642568111
# train acc: 0.72308
# eval acc: 0.6567
# ----------------
# epoch: 8, loss: 0.8013
# accumulate time 53.3401429653
# train acc: 0.74768
# eval acc: 0.6669
# ----------------
# epoch: 9, loss: 0.7509
# accumulate time 60.0482378006
# train acc: 0.75998
# eval acc: 0.6694
# ----------------
# epoch: 10, loss: 0.7067
# accumulate time 66.7232978344
# train acc: 0.78252
# eval acc: 0.6779
# ----------------
# epoch: 11, loss: 0.6620
# accumulate time 73.4094109535
# train acc: 0.80034
# eval acc: 0.6807
# ----------------
# epoch: 12, loss: 0.6211
# accumulate time 80.1044669151
# train acc: 0.81456
# eval acc: 0.6762
# ----------------
# epoch: 13, loss: 0.5833
# accumulate time 86.7735919952
# train acc: 0.83036
# eval acc: 0.6818
# ----------------
# epoch: 14, loss: 0.5467
# accumulate time 93.4627029896
# train acc: 0.84396
# eval acc: 0.6803
# ----------------
# epoch: 15, loss: 0.5115
# accumulate time 100.14889884
# train acc: 0.8556
# eval acc: 0.6815
# ----------------
# epoch: 16, loss: 0.4788
# accumulate time 106.851660967
# train acc: 0.87068
# eval acc: 0.684
# ----------------
# epoch: 17, loss: 0.4463
# accumulate time 113.558900833
# train acc: 0.8826
# eval acc: 0.681
# ----------------
# epoch: 18, loss: 0.4143
# accumulate time 120.262917995
# train acc: 0.8962
# eval acc: 0.6773
# ----------------
# epoch: 19, loss: 0.3826
# accumulate time 126.946245909
# train acc: 0.90768
# eval acc: 0.676
# ----------------
# epoch: 20, loss: 0.3535
# accumulate time 133.66554594
# train acc: 0.91664
# eval acc: 0.6734
# ----------------
# time: 133.666657925

# %%
x = range(len(wn_train_acc))
plt.figure()
plt.plot(x, wn_train_acc, 'r-', label='Weight Norm')
plt.plot(x, wn_kfac_train_acc, 'b-', label='Weight Norm K-FAC')
plt.plot(x, train_acc, 'g-', label='Normal')
plt.plot(x, kfac_train_acc, 'c-', label='Normal K-FAC')
plt.ylabel('Train Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')


#plt.show()
plt.savefig('./plots/train-acc.png')

plt.figure()
plt.plot(x, wn_test_acc, 'r-', label='Weight Norm')
plt.plot(x, wn_kfac_test_acc, 'b-', label='Weight Norm K-FAC')
plt.plot(x, test_acc, 'g-', label='Normal')
plt.plot(x, kfac_test_acc, 'c-', label='Normal K-FAC')
plt.legend(loc='lower right')
plt.ylabel('Test Accuracy')
plt.xlabel('Epoch')

#plt.show()
plt.savefig('./plots/test-acc.png')

plt.figure()
plt.plot(wn_times, wn_test_acc, 'r-', label='Weight Norm')
plt.plot(wn_kfac_times, wn_kfac_test_acc, 'b-', label='Weight Norm K-FAC')
plt.plot(times, test_acc, 'g-', label='Normal')
plt.plot(kfac_times, kfac_test_acc, 'c-', label='Normal K-FAC')
plt.ylabel('Test Accuracy')
plt.xlabel('Time')
plt.legend(loc='lower right')

#plt.show()
plt.savefig('./plots/acc-time.png')

# %%
plt.figure()

plt.plot(x, wn_train_acc, 'r-', label='Train')
plt.plot(x, wn_test_acc, 'b-', label='Test')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.title('Weight Norm')

#plt.show()
plt.savefig('./plots/wn.png')

plt.figure()

plt.plot(x, wn_kfac_train_acc, 'r-', label='Train')
plt.plot(x, wn_kfac_test_acc, 'b-', label='Test')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.title('Weight Norm K-FAC')

#plt.show()
plt.savefig('./plots/wn-kfac.png')

plt.figure()

plt.plot(x, train_acc, 'r-', label='Train')
plt.plot(x, test_acc, 'b-', label='Test')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.title('Normal')

#plt.show()
plt.savefig('./plots/normal.png')

plt.figure()

plt.plot(x, kfac_train_acc, 'r-', label='Train')
plt.plot(x, kfac_test_acc, 'b-', label='Test')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.title('Normal K-FAC')

#plt.show()
plt.savefig('./plots/normal-kfac.png')
